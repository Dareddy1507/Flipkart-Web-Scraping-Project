# %%
import requests
from bs4 import BeautifulSoup
import re
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://www.flipkart.com/search?q=shirts+men&sid=clo%2Cash%2Caxc%2Cmmk%2Ckp7&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&as-pos=1&as-type=RECENT&suggestionId=shirts+men%7CCasual+Shirts&requestId=1ee1b492-068a-4587-8b93-2a9301f3d728&as-searchtext=shir'
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text)

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup.find_all('div',class_="syl9yP")[0].text
# Out:
# 'SPOQUE'

# %%
p = soup.find_all('div',class_="syl9yP")
brands = []
for i in p:
    brands.append(i.text)

# %%
brands
# Out:
# ['SPOQUE',
#  'Force',
#  'Roadster',
#  'Mast & Harbour',
#  'COMBRAIDED',
#  'SPOQUE',
#  'CAMPUS SUTRA',
#  'PARX',
#  'MISHREE',
#  'KETCH',
#  'Vellical',
#  'DEEMOON',
#  'THE BEAR HOUSE',
#  'METRONAUT',
#  'MOONBELL',
#  'METRONAUT PLUS',
#  'SPOQUE',
#  'Wrangler',
#  'HIGHLANDER',
#  'ADWYN PETER',
#  'FUBACK',
#  'THE BEAR HOUSE',
#  'VeBNoR',
#  'METRONAUT',
#  'VIVESCO',
#  'VASTRADO',
#  'COMBRAIDED',
#  'THE BEAR HOUSE',
#  'METRONAUT',
#  'HOC',
#  'WOXEN',
#  'FLYING MACHINE',
#  'Surhi',
#  'JACKBELLA',
#  'V-MART',
#  'METRONAUT',
#  'Force',
#  'Vellical',
#  'N AND J',
#  'Allen Solly']

# %%
len(brands)
# Out:
# 40

# %%
soup.find_all('a',class_="WKTcLC")[0].text.split()[1:3]
# Out:
# ['Regular', 'Fit']

# %%
p = soup.find_all('a', class_="WKTcLC")
style = []
import numpy as np
for i in p:
    joined_words = " ".join(i.text.split()[1:3])
    style.append(joined_words)

expected_length = 45
while len(style) < expected_length:
    style.append(np.nan)

# %%
style
# Out:
# ['Regular Fit',
#  'Regular Fit',
#  'Regular Fit',
#  'Regular Fit',
#  'Regular Fit',
#  'Regular Fit',
#  'Regular Fit',
#  'Slim Fit',
#  'Regular Fit',
#  'Slim Fit',
#  'Slim Fit',
#  'Regular Fit',
#  'Slim Fit',
#  'Regular Fit',
#  'Slim Fit',
#  'Regular Fit',
#  'Regular Fit',
#  'Regular Fit',
#  'Slim Fit',
#  'Regular Fit',
#  'Regular Fit',
#  'Regular Fit',
#  'Regular Fit',
#  'Regular Fit',
#  'Regular Fit',
#  'Regular Fit',
#  'Slim Fit',
#  'Slim Fit',
#  'Regular Fit',
#  'Slim Fit',
#  'Regular Fit',
#  'Slim Fit',
#  'Regular Fit',
#  'Regular Fit',
#  'Slim Fit',
#  'Regular Fit',
#  'Regular Fit',
#  'Slim Fit',
#  'Slim Fit',
#  'Slim Fit',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan]

# %%
len(style)
# Out:
# 45

# %%
soup.find_all('a',class_="WKTcLC")[0].text.split()[4:7]
# Out:
# ['Spread', 'Collar', 'Casual']

# %%
p = soup.find_all('a', class_="WKTcLC")
collar_type = []

for i in p:
    # take 5th to 7th word and join into one string
    joined_words = " ".join(i.text.split()[4:7])
    collar_type.append(joined_words)

# Fill remaining with NaN to make length 45
expected_length = 45
while len(collar_type) < expected_length:
    collar_type.append(np.nan)

# %%
len(collar_type)
# Out:
# 45

# %%
soup.find_all('div',class_="Nx9bqj")[0].text
# Out:
# '₹347'

# %%
p = soup.find_all('div',class_="Nx9bqj")
discount_price = []
for i in p:
    discount_price.append(i.text)

# %%
len(discount_price)
# Out:
# 45

# %%
soup.find_all('div',class_="yRaY8j")[0].text
# Out:
# '₹1,499'

# %%
import numpy as np  # for NaN

p = soup.find_all('div', class_="yRaY8j")
original_price = [i.text for i in p]  # list of scraped prices

expected_length = 45
while len(original_price) < expected_length:
    original_price.append(np.nan)  # fill remaining with NaN

# %%
len(original_price)
# Out:
# 45

# %%
soup.find_all('div',class_="UkUFwK")[0].text
# Out:
# '76% off'

# %%
p = soup.find_all('div',class_="UkUFwK")
discount_percentage = []
for i in p:
    discount_percentage .append(i.text)

# %%
len(discount_percentage)
# Out:
# 44

# %%
len(brands)
# Out:
# 40

# %%
len(style)
# Out:
# 45

# %%
len(collar_type)
# Out:
# 45

# %%
len(discount_price)
# Out:
# 45

# %%
len(original_price)
# Out:
# 45

# %%
brands = []
style = []
collar_type = []
discount_price = []
original_price = []
discount_percentage = []




for i in range(2,11):
    print('https://www.flipkart.com/search?q=shirts+men&sid=clo%2Cash%2Caxc%2Cmmk%2Ckp7&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&as-pos=1&as-type=RECENT&suggestionId=shirts+men%7CCasual+Shirts&requestId=1ee1b492-068a-4587-8b93-2a9301f3d728&as-searchtext=shir'+str(i))
    url = 'https://www.flipkart.com/search?q=shirts+men&sid=clo%2Cash%2Caxc%2Cmmk%2Ckp7&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&as-pos=1&as-type=RECENT&suggestionId=shirts+men%7CCasual+Shirts&requestId=1ee1b492-068a-4587-8b93-2a9301f3d728&as-searchtext=shir'+str(i)
    response = requests.get(url)
    soup = BeautifulSoup(response.text)
        
    p = soup.find_all('div',class_="syl9yP")
    for i in p:
        brands.append(i.text)
    
    
    p = soup.find_all('a', class_="WKTcLC")
    
    for i in p:
        joined_words = " ".join(i.text.split()[1:3])
        style.append(joined_words)
    
    expected_length = 45
    while len(style) < expected_length:
        style.append(np.nan)
    
    p = soup.find_all('a', class_="WKTcLC")
    for i in p:
        joined_words = " ".join(i.text.split()[4:7])
        collar_type.append(joined_words)
    
    expected_length = 45
    while len(collar_type) < expected_length:
        collar_type.append(np.nan)
    
    p = soup.find_all('div',class_="Nx9bqj")
    for i in p:
        discount_price.append(i.text)
    
    p = soup.find_all('div', class_="yRaY8j")
    original_price = [i.text for i in p]  
    
    expected_length = 45
    while len(original_price) < expected_length:
        original_price.append(np.nan)  
    
    p = soup.find_all('div',class_="UkUFwK")
    for i in p:
        discount_percentage .append(i.text)
# Out:
# https://www.flipkart.com/search?q=shirts+men&sid=clo%2Cash%2Caxc%2Cmmk%2Ckp7&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&as-pos=1&as-type=RECENT&suggestionId=shirts+men%7CCasual+Shirts&requestId=1ee1b492-068a-4587-8b93-2a9301f3d728&as-searchtext=shir2
# https://www.flipkart.com/search?q=shirts+men&sid=clo%2Cash%2Caxc%2Cmmk%2Ckp7&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&as-pos=1&as-type=RECENT&suggestionId=shirts+men%7CCasual+Shirts&requestId=1ee1b492-068a-4587-8b93-2a9301f3d728&as-searchtext=shir3
# https://www.flipkart.com/search?q=shirts+men&sid=clo%2Cash%2Caxc%2Cmmk%2Ckp7&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&as-pos=1&as-type=RECENT&suggestionId=shirts+men%7CCasual+Shirts&requestId=1ee1b492-068a-4587-8b93-2a9301f3d728&as-searchtext=shir4
# https://www.flipkart.com/search?q=shirts+men&sid=clo%2Cash%2Caxc%2Cmmk%2Ckp7&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&as-pos=1&as-type=RECENT&suggestionId=shirts+men%7CCasual+Shirts&requestId=1ee1b492-068a-4587-8b93-2a9301f3d728&as-searchtext=shir5
# https://www.flipkart.com/search?q=shirts+men&sid=clo%2Cash%2Caxc%2Cmmk%2Ckp7&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&as-pos=1&as-type=RECENT&suggestionId=shirts+men%7CCasual+Shirts&requestId=1ee1b492-068a-4587-8b93-2a9301f3d728&as-searchtext=shir6
# https://www.flipkart.com/search?q=shirts+men&sid=clo%2Cash%2Caxc%2Cmmk%2Ckp7&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&as-pos=1&as-type=RECENT&suggestionId=shirts+men%7CCasual+Shirts&requestId=1ee1b492-068a-4587-8b93-2a9301f3d728&as-searchtext=shir7
# https://www.flipkart.com/search?q=shirts+men&sid=clo%2Cash%2Caxc%2Cmmk%2Ckp7&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&as-pos=1&as-type=RECENT&suggestionId=shirts+men%7CCasual+Shirts&requestId=1ee1b492-068a-4587-8b93-2a9301f3d728&as-searchtext=shir8
# https://www.flipkart.com/search?q=shirts+men&sid=clo%2Cash%2Caxc%2Cmmk%2Ckp7&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&as-pos=1&as-type=RECENT&suggestionId=shirts+men%7CCasual+Shirts&requestId=1ee1b492-068a-4587-8b93-2a9301f3d728&as-searchtext=shir9
# https://www.flipkart.com/search?q=shirts+men&sid=clo%2Cash%2Caxc%2Cmmk%2Ckp7&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&as-pos=1&as-type=RECENT&suggestionId=shirts+men%7CCasual+Shirts&requestId=1ee1b492-068a-4587-8b93-2a9301f3d728&as-searchtext=shir10

# %%
len(original_price)
# Out:
# 45

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# Lists to store data
brands = []
style = []
collar_type = []
discount_price = []
original_price = []
discount_percentage = []

# Loop through pages
for i in range(2, 31):
    url = f'https://www.flipkart.com/search?q=shirts+men&as-searchtext=shir{i}'
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Brands
    for b in soup.find_all('div', class_="syl9yP"):
        brands.append(b.text)
    
    # Style & Collar type
    for a in soup.find_all('a', class_="WKTcLC"):
        words = a.text.split()
        style.append(" ".join(words[1:3]) if len(words) > 2 else np.nan)
        collar_type.append(" ".join(words[4:7]) if len(words) > 6 else np.nan)
    
    # Discount price
    for dp in soup.find_all('div', class_="Nx9bqj"):
        discount_price.append(dp.text)
    
    # Original price
    for op in soup.find_all('div', class_="yRaY8j"):
        original_price.append(op.text)
    
    # Discount percentage
    for dper in soup.find_all('div', class_="UkUFwK"):
        discount_percentage.append(dper.text)

# Find the maximum length among all lists
max_length = max(len(brands), len(style), len(collar_type), len(discount_price), len(original_price), len(discount_percentage))

# Pad all lists with NaN to make lengths equal
for lst in [brands, style, collar_type, discount_price, original_price, discount_percentage]:
    while len(lst) < max_length:
        lst.append(np.nan)

# Create DataFrame
df = pd.DataFrame({
    'Brand': brands,
    'Style': style,
    'Collar Type': collar_type,
    'Discount Price': discount_price,
    'Original Price': original_price,
    'Discount Percentage': discount_percentage
})

# %%
len(original_price)
# Out:
# 1305

# %%
len(brands)
# Out:
# 1305

# %%
len(style)
# Out:
# 1305

# %%
len(collar_type)
# Out:
# 1305

# %%
len(discount_price)
# Out:
# 1305

# %%
len(discount_percentage)
# Out:
# 1305

# %%
df
# Out:
#                           Brand         Style           Collar Type  \
# 0               U.S. POLO ASSN.  Tailored Fit    Button Down Collar
# 1     United Colors of Benetton   Regular Fit                   NaN
# 2                      Roadster   Regular Fit  Spread Collar Casual
# 3                Mast & Harbour   Regular Fit   Design Casual Shirt
# 4                       Solbiza   Regular Fit    Slim Collar Casual
# ...                         ...           ...                   ...
# 1300                        NaN           NaN                   NaN
# 1301                        NaN           NaN                   NaN
# 1302                        NaN           NaN                   NaN
# 1303                        NaN           NaN                   NaN
# 1304                        NaN           NaN                   NaN
#
#      Discount Price Original Price Discount Percentage
# 0            ₹2,321         ₹2,699             14% off
# 1            ₹1,253         ₹3,299             62% off
# 2              ₹404         ₹1,499             73% off
# 3              ₹811         ₹2,799             71% off
# 4              ₹448         ₹1,599             71% off
# ...             ...            ...                 ...
# 1300           ₹264            NaN                 NaN
# 1301           ₹423            NaN                 NaN
# 1302           ₹610            NaN                 NaN
# 1303           ₹409            NaN                 NaN
# 1304           ₹409            NaN                 NaN
#
# [1305 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1305 entries, 0 to 1304
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brand                1160 non-null   object
#  1   Style                1160 non-null   object
#  2   Collar Type          1017 non-null   object
#  3   Discount Price       1305 non-null   object
#  4   Original Price       1147 non-null   object
#  5   Discount Percentage  1278 non-null   object
# dtypes: object(6)
# memory usage: 61.3+ KB

# %%
df[df.duplicated]
# Out:
#                Brand        Style           Collar Type Discount Price  \
# 33          VASTRADO  Regular Fit                   NaN           ₹570
# 85            SPOQUE  Regular Fit  Spread Collar Casual           ₹610
# 90            SPOQUE  Regular Fit  Design Spread Collar           ₹347
# 95         METRONAUT  Regular Fit  Spread Collar Casual           ₹347
# 96            SPOQUE  Regular Fit  Design Spread Collar           ₹680
# 100           SPOQUE  Regular Fit  Spread Collar Casual           ₹347
# 101         Wrangler  Regular Fit  Spread Collar Casual           ₹347
# 121            USONA  Regular Fit  Spread Collar Casual           ₹426
# 123   Mast & Harbour  Regular Fit   Design Casual Shirt           ₹570
# 125           SPOQUE  Regular Fit  Spread Collar Casual           ₹499
# 131          DEEMOON  Regular Fit    Button Down Collar           ₹409
# 135        METRONAUT  Regular Fit  Spread Collar Casual           ₹347
# 136           SPOQUE  Regular Fit  Design Spread Collar           ₹304
# 140         Wrangler  Regular Fit  Spread Collar Casual           ₹347
# 151           SPOQUE  Regular Fit  Design Spread Collar           ₹347
# 156   THE BEAR HOUSE  Regular Fit    Button Down Collar           ₹338
# 180         Wrangler  Regular Fit  Spread Collar Casual           ₹347
# 184        STONEBERG     Slim Fit  Spread Collar Formal           ₹347
# 1146  THE BEAR HOUSE  Regular Fit    Button Down Collar           ₹338
# 1186             NaN          NaN                   NaN           ₹347
# 1187             NaN          NaN                   NaN           ₹347
# 1205             NaN          NaN                   NaN           ₹499
# 1207             NaN          NaN                   NaN           ₹998
# 1208             NaN          NaN                   NaN           ₹858
# 1209             NaN          NaN                   NaN           ₹878
# 1213             NaN          NaN                   NaN           ₹570
# 1214             NaN          NaN                   NaN           ₹426
# 1215             NaN          NaN                   NaN           ₹347
# 1218             NaN          NaN                   NaN           ₹811
# 1222             NaN          NaN                   NaN           ₹300
# 1223             NaN          NaN                   NaN           ₹759
# 1224             NaN          NaN                   NaN           ₹285
# 1225             NaN          NaN                   NaN           ₹347
# 1228             NaN          NaN                   NaN           ₹475
# 1229             NaN          NaN                   NaN           ₹449
# 1230             NaN          NaN                   NaN           ₹289
# 1232             NaN          NaN                   NaN           ₹347
# 1236             NaN          NaN                   NaN           ₹615
# 1237             NaN          NaN                   NaN           ₹401
# 1238             NaN          NaN                   NaN           ₹329
# 1239             NaN          NaN                   NaN           ₹279
# 1244             NaN          NaN                   NaN           ₹372
# 1247             NaN          NaN                   NaN           ₹570
# 1248             NaN          NaN                   NaN           ₹570
# 1250             NaN          NaN                   NaN           ₹499
# 1253             NaN          NaN                   NaN           ₹858
# 1256             NaN          NaN                   NaN           ₹409
# 1257             NaN          NaN                   NaN           ₹615
# 1261             NaN          NaN                   NaN           ₹347
# 1275             NaN          NaN                   NaN           ₹289
# 1276             NaN          NaN                   NaN           ₹426
# 1300             NaN          NaN                   NaN           ₹264
# 1301             NaN          NaN                   NaN           ₹423
# 1302             NaN          NaN                   NaN           ₹610
# 1303             NaN          NaN                   NaN           ₹409
# 1304             NaN          NaN                   NaN           ₹409
#
#      Original Price Discount Percentage
# 33           ₹1,899             69% off
# 85           ₹1,499             53% off
# 90           ₹1,499             76% off
# 95           ₹1,399             76% off
# 96           ₹1,499             65% off
# 100          ₹1,499             76% off
# 101          ₹2,199             76% off
# 121          ₹1,599             80% off
# 123          ₹2,799             69% off
# 125          ₹1,499             61% off
# 131          ₹1,499             74% off
# 135          ₹1,399             76% off
# 136          ₹1,499             80% off
# 140          ₹2,199             76% off
# 151          ₹1,499             76% off
# 156          ₹2,495             83% off
# 180          ₹2,199             76% off
# 184          ₹1,599             76% off
# 1146         ₹2,495             76% off
# 1186            NaN             74% off
# 1187            NaN             72% off
# 1205            NaN             79% off
# 1207            NaN             76% off
# 1208            NaN             86% off
# 1209            NaN             58% off
# 1213            NaN             78% off
# 1214            NaN             86% off
# 1215            NaN             74% off
# 1218            NaN             87% off
# 1222            NaN             69% off
# 1223            NaN             69% off
# 1224            NaN             53% off
# 1225            NaN             61% off
# 1228            NaN             66% off
# 1229            NaN             64% off
# 1230            NaN             53% off
# 1232            NaN             72% off
# 1236            NaN             76% off
# 1237            NaN             73% off
# 1238            NaN             71% off
# 1239            NaN             76% off
# 1244            NaN             84% off
# 1247            NaN             70% off
# 1248            NaN             52% off
# 1250            NaN             79% off
# 1253            NaN             86% off
# 1256            NaN             76% off
# 1257            NaN             59% off
# 1261            NaN             60% off
# 1275            NaN             53% off
# 1276            NaN             74% off
# 1300            NaN                 NaN
# 1301            NaN                 NaN
# 1302            NaN                 NaN
# 1303            NaN                 NaN
# 1304            NaN                 NaN

# %%
# Remove duplicate rows
df = df.drop_duplicates()

# Reset index (optional, makes it clean)
df = df.reset_index(drop=True)

print(df.head())
# Out:
#                        Brand         Style           Collar Type  \
# 0            U.S. POLO ASSN.  Tailored Fit    Button Down Collar
# 1  United Colors of Benetton   Regular Fit                   NaN
# 2                   Roadster   Regular Fit  Spread Collar Casual
# 3             Mast & Harbour   Regular Fit   Design Casual Shirt
# 4                    Solbiza   Regular Fit    Slim Collar Casual
#
#   Discount Price Original Price Discount Percentage
# 0         ₹2,321         ₹2,699             14% off
# 1         ₹1,253         ₹3,299             62% off
# 2           ₹404         ₹1,499             73% off
# 3           ₹811         ₹2,799             71% off
# 4           ₹448         ₹1,599             71% off

# %%
df
# Out:
#                           Brand         Style           Collar Type  \
# 0               U.S. POLO ASSN.  Tailored Fit    Button Down Collar
# 1     United Colors of Benetton   Regular Fit                   NaN
# 2                      Roadster   Regular Fit  Spread Collar Casual
# 3                Mast & Harbour   Regular Fit   Design Casual Shirt
# 4                       Solbiza   Regular Fit    Slim Collar Casual
# ...                         ...           ...                   ...
# 1244                        NaN           NaN                   NaN
# 1245                        NaN           NaN                   NaN
# 1246                        NaN           NaN                   NaN
# 1247                        NaN           NaN                   NaN
# 1248                        NaN           NaN                   NaN
#
#      Discount Price Original Price Discount Percentage
# 0            ₹2,321         ₹2,699             14% off
# 1            ₹1,253         ₹3,299             62% off
# 2              ₹404         ₹1,499             73% off
# 3              ₹811         ₹2,799             71% off
# 4              ₹448         ₹1,599             71% off
# ...             ...            ...                 ...
# 1244           ₹499            NaN                 NaN
# 1245           ₹404            NaN                 NaN
# 1246         ₹1,198            NaN                 NaN
# 1247           ₹497            NaN                 NaN
# 1248           ₹878            NaN                 NaN
#
# [1249 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1249 entries, 0 to 1248
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brand                1141 non-null   object
#  1   Style                1141 non-null   object
#  2   Collar Type          999 non-null    object
#  3   Discount Price       1249 non-null   object
#  4   Original Price       1128 non-null   object
#  5   Discount Percentage  1227 non-null   object
# dtypes: object(6)
# memory usage: 58.7+ KB

# %%
df['Collar Type'].mode()[0]
# Out:
# 'Spread Collar Casual'

# %%
df.fillna({'Collar Type': df['Collar Type'].mode()[0]}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1249 entries, 0 to 1248
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brand                1141 non-null   object
#  1   Style                1141 non-null   object
#  2   Collar Type          1249 non-null   object
#  3   Discount Price       1249 non-null   object
#  4   Original Price       1128 non-null   object
#  5   Discount Percentage  1227 non-null   object
# dtypes: object(6)
# memory usage: 58.7+ KB

# %%
df['Style'].mode()[0]
# Out:
# 'Regular Fit'

# %%
df['Style'].fillna(df['Style'].mode()[0])
# Out:
# 0       Tailored Fit
# 1        Regular Fit
# 2        Regular Fit
# 3        Regular Fit
# 4        Regular Fit
#             ...
# 1244     Regular Fit
# 1245     Regular Fit
# 1246     Regular Fit
# 1247     Regular Fit
# 1248     Regular Fit
# Name: Style, Length: 1249, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1249 entries, 0 to 1248
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brand                1141 non-null   object
#  1   Style                1249 non-null   object
#  2   Collar Type          1249 non-null   object
#  3   Discount Price       1249 non-null   object
#  4   Original Price       1128 non-null   object
#  5   Discount Percentage  1227 non-null   object
# dtypes: object(6)
# memory usage: 58.7+ KB

# %%
df['Original Price'] = df['Original Price'].str.replace('₹','').str.replace(',','')

# %%
df['Original Price'].mode()
# Out:
# 0    1499
# Name: Original Price, dtype: object

# %%
df['Original Price'].fillna(df['Original Price'].mode()[0])
# Out:
# 0       2699
# 1       3299
# 2       1499
# 3       2799
# 4       1599
#         ...
# 1244    1499
# 1245    1499
# 1246    1499
# 1247    1499
# 1248    1499
# Name: Original Price, Length: 1249, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1249 entries, 0 to 1248
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brand                1141 non-null   object
#  1   Style                1249 non-null   object
#  2   Collar Type          1249 non-null   object
#  3   Discount Price       1249 non-null   object
#  4   Original Price       1128 non-null   object
#  5   Discount Percentage  1227 non-null   object
# dtypes: object(6)
# memory usage: 58.7+ KB

# %%
df['Original Price'] = df['Original Price'].fillna(0).astype(int)

# %%
df['Original Price']
# Out:
# 0       2699
# 1       3299
# 2       1499
# 3       2799
# 4       1599
#         ...
# 1244       0
# 1245       0
# 1246       0
# 1247       0
# 1248       0
# Name: Original Price, Length: 1249, dtype: int32

# %%
df['Discount Price'] = df['Discount Price'].str.replace('₹','').str.replace(',','')

# %%
df['Discount Price'] = df['Discount Price'].astype(int)

# %%
df['Brand'].mode()[0]
# Out:
# 'SPOQUE'

# %%
df['Brand'].fillna(df['Brand'].mode()[0])
# Out:
# 0                 U.S. POLO ASSN.
# 1       United Colors of Benetton
# 2                        Roadster
# 3                  Mast & Harbour
# 4                         Solbiza
#                   ...
# 1244                       SPOQUE
# 1245                       SPOQUE
# 1246                       SPOQUE
# 1247                       SPOQUE
# 1248                       SPOQUE
# Name: Brand, Length: 1249, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1249 entries, 0 to 1248
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brand                1249 non-null   object
#  1   Style                1249 non-null   object
#  2   Collar Type          1249 non-null   object
#  3   Discount Price       1249 non-null   int32
#  4   Original Price       1249 non-null   int32
#  5   Discount Percentage  1227 non-null   object
# dtypes: int32(2), object(4)
# memory usage: 48.9+ KB

# %%
def find_outliers_iqr(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    outliers = data[(data < lower) | (data > upper)]
    return outliers

# %%
discount_outliers = find_outliers_iqr(df['Discount Price'])
original_outliers = find_outliers_iqr(df['Original Price'])
print("Discount Price Outliers:\n", discount_outliers)
print("Original Price Outliers:\n", original_outliers)
# Out:
# Discount Price Outliers:
#  0       2321
# 1       1253
# 17      1855
# 26      1691
# 36      1199
# 40      1855
# 43      1253
# 173     2321
# 199     1198
# 218     2321
# 244     1198
# 252     2321
# 269     1691
# 282     1198
# 353     2321
# 379     1198
# 443     2321
# 469     1198
# 578     2321
# 604     1198
# 612     2321
# 613     1253
# 629     1855
# 633     1691
# 649     1199
# 653     1855
# 656     1253
# 657     2321
# 674     1691
# 688     1855
# 699     1855
# 702     2321
# 719     1691
# 732     1198
# 758     2321
# 784     1198
# 848     2321
# 874     1198
# 893     2321
# 919     1198
# 972     2321
# 989     1691
# 1002    1198
# 1028    2321
# 1062    2321
# 1079    1691
# 1092    1399
# 1093    1855
# 1103    1855
# 1222    2321
# 1246    1198
# Name: Discount Price, dtype: int32
# Original Price Outliers:
#  1       3299
# 17      3199
# 221     3199
# 537     3299
# 553     3199
#         ...
# 1244       0
# 1245       0
# 1246       0
# 1247       0
# 1248       0
# Name: Original Price, Length: 131, dtype: int32

# %%
df = df[~df['Discount Price'].isin(discount_outliers)]
df = df[~df['Original Price'].isin(original_outliers)]
df = df.reset_index(drop=True)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1071 entries, 0 to 1070
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brand                1071 non-null   object
#  1   Style                1071 non-null   object
#  2   Collar Type          1071 non-null   object
#  3   Discount Price       1071 non-null   int32
#  4   Original Price       1071 non-null   int32
#  5   Discount Percentage  1071 non-null   object
# dtypes: int32(2), object(4)
# memory usage: 42.0+ KB
# None

# %%
df
# Out:
#                Brand        Style           Collar Type  Discount Price  \
# 0           Roadster  Regular Fit  Spread Collar Casual             404
# 1     Mast & Harbour  Regular Fit   Design Casual Shirt             811
# 2            Solbiza  Regular Fit    Slim Collar Casual             448
# 3           Vellical     Slim Fit  Spread Collar Casual             404
# 4       CAMPUS SUTRA  Regular Fit  Spread Collar Casual             680
# ...              ...          ...                   ...             ...
# 1066          VezVoR  Regular Fit   Spread Collar Party             347
# 1067      HIGHLANDER     Slim Fit  Spread Collar Casual             347
# 1068       METRONAUT  Regular Fit  Spread Collar Casual             276
# 1069       STONEBERG     Slim Fit  Spread Collar Formal             410
# 1070       JACKBELLA  Regular Fit  Spread Collar Casual             615
#
#       Original Price Discount Percentage
# 0               1499             73% off
# 1               2799             71% off
# 2               1599             71% off
# 3               1399             71% off
# 4               1999             65% off
# ...              ...                 ...
# 1066            1299             72% off
# 1067            2599             58% off
# 1068            1399             69% off
# 1069            1199             80% off
# 1070            1999             76% off
#
# [1071 rows x 6 columns]

# %%
# For categorical columns (Brand, Style, Collar Type, Discount Percentage):

# %%
sns.countplot(data=df, x='Brand')
plt.xticks(rotation=90)
plt.show()

# %%
#For numerical columns (Discount Price, Original Price):

# %%
df[['Discount Price','Original Price']].hist(bins=20, figsize=(10,5))
plt.show()

# %%
sns.boxplot(data=df[['Discount Price','Original Price']])
plt.show()

# %%
# Bivariate Analysis

# %%
# Numerical vs Numerical

# %%
sns.scatterplot(data=df, x='Original Price', y='Discount Price')
plt.show()

# Correlation
print(df[['Original Price','Discount Price']].corr())
# Out:
#                 Original Price  Discount Price
# Original Price        1.000000       -0.017902
# Discount Price       -0.017902        1.000000

# %%
# Numerical vs Categorical

# %%
sns.boxplot(data=df, x='Brand', y='Discount Price')
plt.xticks(rotation=90)
plt.show()

# %%
# Categorical vs Categorical

# %%
sns.countplot(data=df, x='Brand', hue='Collar Type')
plt.xticks(rotation=90)
plt.show()

# %%
# Multivariate Analysis

# %%
sns.pairplot(df, vars=['Discount Price','Original Price'], hue='Brand')
plt.show()

# %%
sns.heatmap(df[['Discount Price','Original Price']].corr(), annot=True, cmap='coolwarm')
plt.show()
